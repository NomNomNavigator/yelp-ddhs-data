# %%
import pandas as pd

# %%
df = pd.read_json('/Users/mike/Documents/yelp_datasets/yelp_dataset/yelp_academic_dataset_business.json', lines=True)

# %%
df.head(5)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
df.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
restuarant_finder = df['categories'].isin(["Food"])

# %%
df2 = df[restuarant_finder]

# %%
df2.head(5)
# Out:
#                   business_id                                           name  \
# 4764   mRWlzIJpyQgatq_J7dzxWw  Audubon Aquarium of the Americas - Food Court
# 5142   KuLi91b-N_0XY_3IA72RJQ                           MexiPhilly Food Cart
# 23198  q-enMHLRAGuFIqp0dr6zqw                                Kernels Popcorn
# 44577  6KLYTdC1qESvw0VaremJbQ                           Taste of the Heights
# 54940  fD3P-GEhl-IrztLEguAMAA                               McAlister's Deli
#
#                                         address          city state  \
# 4764                                 1 Canal St   New Orleans    LA
# 5142                      37TH St And Spruce St  Philadelphia    PA
# 23198  West Edmonton Mall, 1840 - 8882 170th St      Edmonton    AB
# 44577                       4500 N Nebraska Ave         Tampa    FL
# 54940                          2271 Pointe Pkwy        Carmel    IN
#
#       postal_code   latitude   longitude  stars  review_count  is_open  \
# ...

# %%
r_finder2 = df['categories'].str.contains('Food')

# %%
df3 = df[r_finder2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df3 = df[r_finder2]
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.8_1/libexec/lib/python3.12/site-packages/pandas/core/frame.py:3883, in DataFrame.__getitem__(self, key)
#    3880     return self.where(key)
#    3882 # Do we have a (boolean) 1d indexer?
# -> 3883 if com.is_bool_indexer(key):
#    3884     return self._getitem_bool_array(key)
#    3886 # We are left with two options: a single key, and a collection of keys,
#    3887 # We interpret tuples as collections only for non-MultiIndex
#
# File /opt/homebrew/Cellar/jupyterlab/4.0.8_1/libexec/lib/python3.12/site-packages/pandas/core/common.py:133, in is_bool_indexer(key)
#     129     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     130     if lib.is_bool_array(key_array, skipna=True):
# ...

# %%
has_blanks = df['categories'].isna().any() or (df['categories'] == '').any()

# %%
if has_blanks:
    print("Categories has blanks or NaN values")
else:
    print("Categories does not have blanks or NaN values")
# Out:
# Categories has blanks or NaN values

# %%
df['categories'] = df['categories'].fillna('nothing')

# %%
has_blanks = df['categories'].isna().any() or (df['categories'] == '').any()

# %%
if has_blanks:
    print("Categories has blanks or NaN values")
else:
    print("Categories does not have blanks or NaN values")
# Out:
# Categories does not have blanks or NaN values

# %%
r_finder3 = df['categories'].str.contains('Food')

# %%
df3 = df[r_finder3]

# %%
df3.head(5)
# Out:
#                business_id                      name              address  \
# 3   MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries          935 Race St
# 4   mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery        101 Walnut St
# 5   CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In        615 S Main St
# 9   bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In  2312 Dickerson Pike
# 11  eEOYSgkmpB90uNA7lDOMRA     Vietnamese Food Truck
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 4     Green Lane    PA       18054  40.338183 -75.471659    4.5            13
# 5   Ashland City    TN       37015  36.269593 -87.058943    2.0             6
# 9      Nashville    TN       37207  36.208102 -86.768170    1.5            10
# 11     Tampa Bay    FL       33602  27.955269 -82.456320    4.0            10
#
#     is_open                                         attributes  \
# ...

# %%
df3.shape[0]
# Out:
# 33405

# %%
df.shape[0]
# Out:
# 150346

# %%
r_finder4 = df['categories'].str.contains('Restaurant')

# %%
df4 = df[r_finder4]

# %%
df4.shape[0]
# Out:
# 52286

# %% [markdown]
# I want to look for any business that describes itself as "Food" or "Restaurant"
# It is not clear yet if "Food" will cause businesses to be included that make no sense - wholesaler for example.

# %%
r_finder5 = df['categories'].str.contains('Restaurant|Food')

# %%
df5 = df[r_finder5]

# %%
df5.shape[0]
# Out:
# 64629

# %%
df5.head(5)
# Out:
#               business_id                      name              address  \
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries          935 Race St
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery        101 Walnut St
# 5  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In        615 S Main St
# 8  k0hlBqXX-Bt0vf1op7Jr1w     Tsevi's Pub And Grill    8025 Mackenzie Rd
# 9  bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In  2312 Dickerson Pike
#
#            city state postal_code   latitude  longitude  stars  review_count  \
# 3  Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 4    Green Lane    PA       18054  40.338183 -75.471659    4.5            13
# 5  Ashland City    TN       37015  36.269593 -87.058943    2.0             6
# 8        Affton    MO       63123  38.565165 -90.321087    3.0            19
# 9     Nashville    TN       37207  36.208102 -86.768170    1.5            10
#
# ...

# %%
df5_philly = df5['city'] == 'Philadelphia'

# %%
df5_philly.shape[0]
# Out:
# 64629

# %%
df5_philly.head(5)
# Out:
# 3     True
# 4    False
# 5    False
# 8    False
# 9    False
# Name: city, dtype: bool

# %%
df5_philly = "foo"

# %%
df5_philly = df5[df5['city'] == 'Philadelphia']

# %%
df5_philly.head(5)
# Out:
#                business_id                name        address          city  \
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries    935 Race St  Philadelphia
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar    205 Race St  Philadelphia
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP  1224 South St  Philadelphia
# 28  QdN72BWoyFypdGJhhI5r7g             Bar One   767 S 9th St  Philadelphia
# 31  Mjboz24M9NlBeiOJKLEd_Q    DeSandro on Main   4105 Main St  Philadelphia
#
#    state postal_code   latitude  longitude  stars  review_count  is_open  \
# 3     PA       19107  39.955505 -75.155564    4.0            80        1
# 15    PA       19106  39.953949 -75.143226    4.0           245        1
# 19    PA       19147  39.943223 -75.162568    4.5           205        1
# 28    PA       19147  39.939825 -75.157447    4.0            65        0
# 31    PA       19127  40.022466 -75.218314    3.0            41        0
#
#                                            attributes  \
# ...

# %%
df5_philly.shape[0]
# Out:
# 7076

# %%
df6 = df[df['city'] == 'Philadelphia']

# %%
df6.shape[0]
# Out:
# 14569

# %%
df6.head(10)
# Out:
#                 business_id                      name  \
# 3    MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 15   MUTTqe8uqyMdBl186RmNeA                  Tuna Bar
# 19   ROeacJQwBeh05Rqg7F6TCg                       BAP
# 28   QdN72BWoyFypdGJhhI5r7g                   Bar One
# 31   Mjboz24M9NlBeiOJKLEd_Q          DeSandro on Main
# 35   aPNXGTDkf-4bjhyMBQxqpQ                Craft Hall
# 76   -4dYswJy7SPcbcERvitmIg                  Pathmark
# 82   ppFCk9aQkM338Rgwpl2F5A                      Wawa
# 84   eMjnw_7wp-CscyNh6Lu0ZA           AM&PM Locksmith
# 115  xfmkEGiIERBaBMLhw-dTCg  Walmart Vision & Glasses
#
#                               address          city state postal_code  \
# 3                         935 Race St  Philadelphia    PA       19107
# 15                        205 Race St  Philadelphia    PA       19106
# 19                      1224 South St  Philadelphia    PA       19147
# 28                       767 S 9th St  Philadelphia    PA       19147
# ...

# %%
df6_rests = df6[df6['categories'].str.contains('Food|Restaurant', case=False)]

# %%
df6_rests.shape[0]
# Out:
# 7076

# %%
df6_rests.to_json('philly_rests_yelp_ds.json', orient='split')

# %%
df6_rests.to_json('philly_rests_yelp_ds.json', orient='records')

# %%
df6_rests.head(3)
# Out:
#                business_id                name        address          city  \
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries    935 Race St  Philadelphia
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar    205 Race St  Philadelphia
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP  1224 South St  Philadelphia
#
#    state postal_code   latitude  longitude  stars  review_count  is_open  \
# 3     PA       19107  39.955505 -75.155564    4.0            80        1
# 15    PA       19106  39.953949 -75.143226    4.0           245        1
# 19    PA       19147  39.943223 -75.162568    4.5           205        1
#
#                                            attributes  \
# 3   {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 15  {'RestaurantsReservations': 'True', 'Restauran...
# 19  {'NoiseLevel': 'u'quiet'', 'GoodForMeal': '{'d...
#
#                                            categories  \
# 3   Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# ...

# %%
df6_rests.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df7_rests = df6_rests[df6_rests['is_open'] == 1]

# %%
df7_rests.shape[0]
# Out:
# 4372
